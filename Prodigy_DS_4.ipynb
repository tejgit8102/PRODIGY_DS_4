# %% [markdown]
# # Task **4**

# %% [markdown]
# Analyze and visualize sentiment patterns in social media data to understand public opinion and attitudes towards specific topics or brands.

# %% [markdown]
# # Dataset

# %% [markdown]
# Twitter Sentiment Analysis Dataset

# %% [markdown]
# # Synopsis

# %% [markdown]
# This is an entity-level sentiment analysis dataset of twitter. Given a message and an entity, the task is to judge the sentiment of the message about the entity. There are three classes in this dataset: Positive, Negative and Neutral. We regard messages that are not relevant to the entity (i.e. Irrelevant) as Neutral.

# %% [markdown]
# ## Loading essential libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud

# %% [markdown]
# ## Importing the dataset

# %%
cols=['ID', 'Topic', 'Sentiment', 'Text']
train = pd.read_csv(r"/content/drive/MyDrive/Prodigy InfoTech/Task 4/twitter_training.csv",names=cols)

# %%
train.head()
# Out:
#      ID        Topic Sentiment  \
# 0  2401  Borderlands  Positive
# 1  2401  Borderlands  Positive
# 2  2401  Borderlands  Positive
# 3  2401  Borderlands  Positive
# 4  2401  Borderlands  Positive
#
#                                                 Text
# 0  im getting on borderlands and i will murder yo...
# 1  I am coming to the borders and I will kill you...
# 2  im getting on borderlands and i will kill you ...
# 3  im coming on borderlands and i will murder you...
# 4  im getting on borderlands 2 and i will murder ...

# %% [markdown]
# ## Dataframe overview

# %%
train.shape
# Out:
# (74682, 4)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74682 entries, 0 to 74681
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   ID         74682 non-null  int64
#  1   Topic      74682 non-null  object
#  2   Sentiment  74682 non-null  object
#  3   Text       73996 non-null  object
# dtypes: int64(1), object(3)
# memory usage: 2.3+ MB

# %%
train.describe(include=object)
# Out:
#                        Topic Sentiment  \
# count                  74682     74682
# unique                    32         4
# top     TomClancysRainbowSix  Negative
# freq                    2400     22542
#
#                                                      Text
# count                                               73996
# unique                                              69491
# top     At the same time, despite the fact that there ...
# freq                                                  172

# %%
train['Sentiment'].unique()
# Out:
# array(['Positive', 'Neutral', 'Negative', 'Irrelevant'], dtype=object)

# %% [markdown]
# ## Looking for null values in the dataset.

# %%
train.isnull().sum()
# Out:
# ID             0
# Topic          0
# Sentiment      0
# Text         686
# dtype: int64

# %%
train.dropna(inplace=True)

# %%
train.isnull().sum()
# Out:
# ID           0
# Topic        0
# Sentiment    0
# Text         0
# dtype: int64

# %% [markdown]
# ## Identifying duplicate entries

# %%
train.duplicated().sum()
# Out:
# 2340

# %%
train.drop_duplicates(inplace=True)

# %%
train.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## Chart depicting the distribution of various topics

# %%
plt.figure(figsize=(8,10))
train['Topic'].value_counts().plot(kind='barh',color='g')
plt.xlabel("Count")
plt.show()

# %% [markdown]
# ## Sentiment Analysis Overview

# %%
sns.countplot(x = 'Sentiment',data=train,palette='viridis')
plt.show()
# Out:
# <ipython-input-15-0f5f2096c1d5>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x = 'Sentiment',data=train,palette='viridis')

# %%
# Calculate the counts for each sentiment
sentiment_counts = train['Sentiment'].value_counts()

# Create the pie chart
plt.figure(figsize=(8, 8))
plt.pie(sentiment_counts, labels=sentiment_counts.index, autopct="%1.1f%%", startangle=140, colors=['skyblue', 'orange', 'green', 'red', 'purple'])

plt.title('Sentiment Distribution')

# Show the plot
plt.show()

# %% [markdown]
# `Observation:`
#
# Most topic has negative sentiment

# %%
train
# Out:
#          ID        Topic Sentiment  \
# 0      2401  Borderlands  Positive
# 1      2401  Borderlands  Positive
# 2      2401  Borderlands  Positive
# 3      2401  Borderlands  Positive
# 4      2401  Borderlands  Positive
# ...     ...          ...       ...
# 74677  9200       Nvidia  Positive
# 74678  9200       Nvidia  Positive
# 74679  9200       Nvidia  Positive
# 74680  9200       Nvidia  Positive
# 74681  9200       Nvidia  Positive
#
#                                                     Text
# 0      im getting on borderlands and i will murder yo...
# 1      I am coming to the borders and I will kill you...
# 2      im getting on borderlands and i will kill you ...
# 3      im coming on borderlands and i will murder you...
# 4      im getting on borderlands 2 and i will murder ...
# ...                                                  ...
# 74677  Just realized that the Windows partition of my...
# 74678  Just realized that my Mac window partition is ...
# ...

# %% [markdown]
# ## Topic-wise Sentiment Analysis

# %%
plt.figure(figsize=(20,12))
sns.countplot(x='Topic',data=train,palette='viridis',hue='Sentiment')
plt.xticks(rotation=90)
plt.show()

# %%
## Group by Topic and Sentiment
topic_wise_sentiment = train.groupby(["Topic", "Sentiment"]).size().reset_index(name='Count')

# Step 2: Select Top 5 Topics
topic_counts = train['Topic'].value_counts().nlargest(5).index
top_topics_sentiment = topic_wise_sentiment[topic_wise_sentiment['Topic'].isin(topic_counts)]

# %% [markdown]
# ## Top 5 Areas with Negative Sentiment

# %%
plt.figure(figsize=(12, 8))
sns.barplot(data=top_topics_sentiment[top_topics_sentiment['Sentiment'] == 'Negative'], x='Topic', y='Count', palette='viridis')
plt.title('Top 5 Topics with Negative Sentiments')
plt.xlabel('Topic')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()
# Out:
# <ipython-input-20-7127521535d3>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=top_topics_sentiment[top_topics_sentiment['Sentiment'] == 'Negative'], x='Topic', y='Count', palette='viridis')

# %% [markdown]
# ## Top 5 Subjects with Positive Feedback

# %%
plt.figure(figsize=(12, 8))
sns.barplot(data=top_topics_sentiment[top_topics_sentiment['Sentiment'] == 'Positive'], x='Topic', y='Count', palette='Greens')
plt.title('Top 5 Topics with Positive Sentiments')
plt.xlabel('Topic')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()
# Out:
# <ipython-input-21-fa26222f4ed6>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=top_topics_sentiment[top_topics_sentiment['Sentiment'] == 'Positive'], x='Topic', y='Count', palette='Greens')

# %% [markdown]
# ## Top 5 Subjects with Neutral Sentiment

# %%
plt.figure(figsize=(12, 8))
sns.barplot(data=top_topics_sentiment[top_topics_sentiment['Sentiment'] == 'Neutral'], x='Topic', y='Count', palette='Blues')
plt.title('Top 5 Topics with Neutral Sentiments')
plt.xlabel('Topic')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()
# Out:
# <ipython-input-22-af01e1bcdbaa>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=top_topics_sentiment[top_topics_sentiment['Sentiment'] == 'Neutral'], x='Topic', y='Count', palette='Blues')

# %% [markdown]
# ## Top 5 Topics with Misaligned Sentiments

# %%
plt.figure(figsize=(12, 8))
sns.barplot(data=top_topics_sentiment[top_topics_sentiment['Sentiment'] == 'Irrelevant'], x='Topic', y='Count', palette='Purples')
plt.title('Top 5 Topics with Irrelevant Sentiments')
plt.xlabel('Topic')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()
# Out:
# <ipython-input-23-7662d01b7d35>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=top_topics_sentiment[top_topics_sentiment['Sentiment'] == 'Irrelevant'], x='Topic', y='Count', palette='Purples')

# %% [markdown]
# ## Google Sentiment Analysis Overview

# %%
# Filter the dataset to include only entries related to the topic 'Google'
google_data = train[train['Topic'] == 'Google']

# Count the occurrences of each sentiment within the filtered dataset
sentiment_counts = google_data['Sentiment'].value_counts()

# Plot the pie chart
plt.figure(figsize=(8, 8))
plt.pie(sentiment_counts, labels=sentiment_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Sentiment Distribution of Topic "Google"')
plt.show()

# %% [markdown]
# ## Microsoft Sentiment Analysis Overview

# %%
# Filter the dataset to include only entries related to the topic 'Microsoft'
ms_data = train[train['Topic'] == 'Microsoft']

# Count the occurrences of each sentiment within the filtered dataset
sentiment_counts = ms_data['Sentiment'].value_counts()

# Plot the pie chart
plt.figure(figsize=(8, 8))
plt.pie(sentiment_counts, labels=sentiment_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Sentiment Distribution of Topic "Microsoft"')
plt.show()

# %%
train['msg_len'] = train['Text'].apply(len)

# %%
train
# Out:
#          ID        Topic Sentiment  \
# 0      2401  Borderlands  Positive
# 1      2401  Borderlands  Positive
# 2      2401  Borderlands  Positive
# 3      2401  Borderlands  Positive
# 4      2401  Borderlands  Positive
# ...     ...          ...       ...
# 74677  9200       Nvidia  Positive
# 74678  9200       Nvidia  Positive
# 74679  9200       Nvidia  Positive
# 74680  9200       Nvidia  Positive
# 74681  9200       Nvidia  Positive
#
#                                                     Text  msg_len
# 0      im getting on borderlands and i will murder yo...       53
# 1      I am coming to the borders and I will kill you...       51
# 2      im getting on borderlands and i will kill you ...       50
# 3      im coming on borderlands and i will murder you...       51
# 4      im getting on borderlands 2 and i will murder ...       57
# ...                                                  ...      ...
# 74677  Just realized that the Windows partition of my...      128
# ...

# %% [markdown]
# ## Histogram of message length distribution in training data

# %%
sns.histplot(train['msg_len'], bins=25,kde=True)
plt.title('Message Length Distribution in Training Data')
plt.ylabel('Frequency')
plt.xlabel('Message Length')
plt.show()

# %% [markdown]
# ## Visualize message length distribution across different sentiments for the training dataset.

# %%
sns.boxplot(data=train, x=train['Sentiment'], y='msg_len', palette='viridis', order=['Positive', 'Negative', 'Neutral', 'Irrelevant'])
plt.title('Message Length Distribution by Sentiment in Training Data')
plt.ylabel('Message Length')
plt.xlabel('Sentiment')
plt.ylim(0,300)
plt.show()
# Out:
# <ipython-input-29-ab60571ae2bf>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=train, x=train['Sentiment'], y='msg_len', palette='viridis', order=['Positive', 'Negative', 'Neutral', 'Irrelevant'])

# %%
# Create the crosstab
crosstab = pd.crosstab(index=train['Topic'], columns=train['Sentiment'])

# Plot the heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(crosstab, cmap='coolwarm', annot=True, fmt='d', linewidths=.5)

# Add labels and title
plt.title('Heatmap of Topic vs Sentiment')
plt.xlabel('Sentiment')
plt.ylabel('Topic')

# Show the plot
plt.show()

# %%
topic_list = ' '.join(crosstab.index)


wc = WordCloud(width=1000, height=500).generate(topic_list)

plt.imshow(wc, interpolation='bilinear')

# %%
corpus = ' '.join(train['Text'])

wc2 = WordCloud(width=1200, height=500).generate(corpus)

plt.imshow(wc2, interpolation='bilinear')

# %% [markdown]
# # **Summary of Findings:**
#
# From the Twitter sentiment analysis, the following key observations can be made:
#
# **`Dominant Topic:`** The topic "TomClancyRainbowSix" is identified as the most frequently discussed subject among the Twitter dataset. This indicates a high level of interest or engagement with this topic within the Twitter community.
#
# **`Sentiment Breakdown:`** The sentiment analysis shows that a significant portion of the topics have a negative sentiment, representing 30.3% of the data. Positive sentiment follows at 27.5%, with neutral sentiment slightly behind at 24.7%. Irrelevant sentiments, while less common, make up 17.5% of the total.
#
# **`*Sentiments of Specific Topics:`** Topics like "Google" and "Microsoft" primarily show neutral sentiments. This suggests that discussions about these tech companies are generally more balanced or impartial.
#
# **`Message Length Analysis:`** The analysis also highlights that most messages are under 400 words. This reflects Twitter users' tendency to express their opinions succinctly within the platform's constraints.
#
# In summary, the sentiment analysis sheds light on the prevailing attitudes and opinions on Twitter. While negative sentiments are more prevalent, a wide range of sentiments is present across different topics.
#
# ---
#
# # **Analysis Conclusion:**
#
# Key insights from the Twitter sentiment analysis are as follows:
#
# **`Prevalent Topic:`** The topic "TomClancyRainbowSix" stands out as the most discussed in the dataset, indicating significant interest or engagement with this subject.
#
# **`Sentiment Distribution:`** Negative sentiment is the most common, representing 30.3% of the sentiments analyzed. Positive sentiment is the next most common at 27.5%, with neutral sentiment at 24.7%. Irrelevant sentiments, though less frequent, account for 17.5% of the data.
#
# **`Specific Topic Sentiments:`** Discussions surrounding "Google" and "Microsoft" are predominantly neutral, suggesting a more balanced or impartial view on these topics.
#
# **`Length of Messages:`** Most analyzed messages are under 400 words, demonstrating that users tend to express their thoughts concisely.
#
# In conclusion, the sentiment analysis reveals a general trend towards negative sentiments, with diverse sentiment expressions across various topics.
